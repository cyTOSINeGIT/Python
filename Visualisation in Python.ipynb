# %%
import pandas as pd

# %%
stores= pd.read_csv('C:\\Users\\Admin\\Downloads\\stores_new.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#usingmatplotlib

plt.grid= True
plt.hist(stores.TotalSales)
plt.xlabel('TotalSales')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#usingseaborn

sb.displot(stores.TotalSales, kde = True, color = 'b')

# %%
#usingpd

stores.TotalSales.plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
stores.plot(x= 'TotalSales', y= 'OperatingCost', kind= 'scatter')
# Out:
# <Axes: xlabel='TotalSales', ylabel='OperatingCost'>

# %%
plt.figure
plt.scatter(x= stores.TotalSales, y= stores.OperatingCost, c= 'Red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure
sb.scatterplot (x= stores.TotalSales, y= stores.OperatingCost, c= 'blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
stores.TotalSales.plot (kind='box')
# Out:
# <Axes: >

# %%
sb.countplot(stores.StoreName)
# Out:
# <Axes: xlabel='count', ylabel='StoreName'>

# %%
stores.columns
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment'],
#       dtype='object')

# %%
stores.pivot_table (index= 'StoreName', values= 'TotalSales', aggfunc = 'sum')
# Out:
#                   TotalSales
# StoreName
# Apparel Zone          1449.1
# Central Store         1106.9
# Digital Bazar         1077.7
# Electronics Zone      1140.8
# Fashion Bazar         1437.0
# Super Bazar            471.6
# Super Market           700.0

# %%
stores.pivot_table (index= 'StoreName', values= 'TotalSales', aggfunc = 'sum').plot (kind= 'bar')
# Out:
# <Axes: xlabel='StoreName'>

# %%
StoresDropna = stores.select_dtypes('float64').dropna(axis=1, how= 'all')

# %%
sb.heatmap(StoresDropna.corr(), annot = True)
# Out:
# <Axes: >

# %%
sb.heatmap(stores.select_dtypes('float64').dropna(axis=1, how= 'all').corr(), annot = True)
# Out:
# <Axes: >

# %%
stores.StoreSegment.value_counts().sort_index
# Out:
# <bound method Series.sort_index of StoreSegment
# 4    12
# 2    10
# 1     7
# 3     3
# Name: count, dtype: int64>

# %%
stores.StoreType.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6, 6))
# Out:
# <Axes: ylabel='count'>

# %%
stores.Location.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6, 6))
# Out:
# <Axes: ylabel='count'>

# %%
stores.StoreSegment
# Out:
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4
# 10    4
# 11    3
# 12    3
# 13    3
# 14    4
# 15    4
# 16    4
# 17    1
# 18    2
# 19    1
# 20    1
# 21    2
# 22    2
# 23    4
# 24    2
# 25    1
# 26    2
# 27    2
# 28    4
# 29    4
# 30    4
# 31    2
# Name: StoreSegment, dtype: int64

# %%
print(stores['StoreSegment'].unique())
# Out:
# [4 1 2 3]

# %%
stores.StoreSegment.value_counts().plot(kind='pie',  autopct='%1.1f%%', figsize=(6, 6))
# Out:
# <Axes: ylabel='count'>

# %%
segment_map = {
    1: 'Budget',
    2: 'Standard',
    3: 'Premium',
    4: 'Outlet'
}

stores['StoreSegment'] = stores['StoreSegment'].map(segment_map)

# %%
segment_map
# Out:
# {1: 'Budget', 2: 'Standard', 3: 'Premium', 4: 'Outlet'}

# %%
stores.StoreSegment.value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6, 6))
# Out:
# <Axes: ylabel='count'>
